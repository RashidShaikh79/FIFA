# %%
# loading the required libraries
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifa = pd.read_csv('players_20.csv')
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  24-06-1987
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  05-02-1985
# 2          A. Robben                         Arjen Robben   30  23-01-1984
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32  03-10-1981
# 4           M. Neuer                         Manuel Neuer   28  27-03-1986
#
#    height_cm  weight_kg  nationality                 club  ...   lwb   ldm  \
# 0        169         67    Argentina         FC Barcelona  ...  62+3  62+3
# 1        185         80     Portugal          Real Madrid  ...  63+3  63+3
# 2        180         80  Netherlands    FC Bayern München  ...  64+3  64+3
# 3        195         95       Sweden  Paris Saint-Germain  ...  61+3  65+3
# 4        193         92      Germany    FC Bayern München  ...   NaN   NaN
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  62+3  62+3  62+3  54+3  45+3  45+3  45+3  54+3
# 1  63+3  63+3  63+3  57+3  52+3  52+3  52+3  57+3
# 2  64+3  64+3  64+3  55+3  46+3  46+3  46+3  55+3
# 3  65+3  65+3  61+3  56+3  55+3  55+3  55+3  56+3
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 104 columns]

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# mentality_aggression
# mentality_interceptions
# mentality_positioning
# mentality_vision
# mentality_penalties
# mentality_composure
# defending_marking
# defending_standing_tackle
# defending_sliding_tackle
# goalkeeping_diving
# goalkeeping_handling
# goalkeeping_kicking
# goalkeeping_positioning
# goalkeeping_reflexes
# ls
# st
# rs
# lw
# lf
# cf
# rf
# rw
# lam
# cam
# ram
# lm
# lcm
# cm
# rcm
# rm
# lwb
# ldm
# cdm
# rdm
# rwb
# lb
# lcb
# cb
# rcb
# rb

# %%
fifa.shape
# Out:
# (15465, 104)

# %%
15465*104
# Out:
# 1608360

# %%
fifa['nationality'].value_counts()
# Out:
# nationality
# England          1579
# Spain            1022
# France            875
# Argentina         861
# Italy             778
#                  ...
# Kyrgyzstan          1
# St Lucia            1
# Montserrat          1
# Indonesia           1
# Liechtenstein       1
# Name: count, Length: 148, dtype: int64

# %%
fifa['nationality'].value_counts()[0:10]
# Out:
# nationality
# England                1579
# Spain                  1022
# France                  875
# Argentina               861
# Italy                   778
# Germany                 695
# Colombia                517
# Republic of Ireland     453
# Mexico                  416
# Chile                   410
# Name: count, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5].keys()
# Out:
# Index(['England', 'Spain', 'France', 'Argentina', 'Italy'], dtype='object', name='nationality')

# %%
fifa['nationality'].value_counts()[0:5]
# Out:
# nationality
# England      1579
# Spain        1022
# France        875
# Argentina     861
# Italy         778
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),list(fifa['nationality'].value_counts()[0:5]),color="g")
plt.show()

# %%
player_salary = fifa[['short_name', 'wage_eur']]
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi         0
# 1  Cristiano Ronaldo         0
# 2          A. Robben         0
# 3     Z. Ibrahimović         0
# 4           M. Neuer         0

# %%
player_salary = player_salary.sort_values(by=['wage_eur'],ascending=False)
player_salary.head()
# Out:
#               short_name  wage_eur
# 15464         P. Tisdale         0
# 0               L. Messi         0
# 1      Cristiano Ronaldo         0
# 2              A. Robben         0
# 3         Z. Ibrahimović         0

# %%
plt.figure(figsize=(5,5))
plt.bar(list(fifa['short_name'].value_counts()[0:5].keys()),list(fifa['wage_eur'].value_counts()[0:5]),color="b")
plt.show()

# %%
fifa['nationality'] == 'Germany'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 15460    False
# 15461    False
# 15462    False
# 15463    False
# 15464    False
# Name: nationality, Length: 15465, dtype: bool

# %%
# Germany
Germany = fifa[fifa['nationality'] == 'Germany']
Germany.head(10)
# Out:
#     sofifa_id                                         player_url  \
# 4      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 8      121944  https://sofifa.com/player/121944/bastian-schwe...
# 13     121939  https://sofifa.com/player/121939/philipp-lahm/...
# 21     178603  https://sofifa.com/player/178603/mats-hummels/...
# 23     188350  https://sofifa.com/player/188350/marco-reus/15...
# 24     189596  https://sofifa.com/player/189596/thomas-muller...
# 26     176635  https://sofifa.com/player/176635/mesut-ozil/15...
# 31     192318  https://sofifa.com/player/192318/mario-gotze/1...
# 33     182521  https://sofifa.com/player/182521/toni-kroos/15...
# 41     183907  https://sofifa.com/player/183907/jerome-boaten...
#
#            short_name               long_name  age         dob  height_cm  \
# 4            M. Neuer            Manuel Neuer   28  27-03-1986        193
# 8   B. Schweinsteiger  Bastian Schweinsteiger   29  01-08-1984        183
# 13            P. Lahm            Philipp Lahm   30  11-11-1983        170
# 21         M. Hummels           Mats  Hummels   25  16-12-1988        192
# 23            M. Reus              Marco Reus   25  31-05-1989        181
# 24          T. Müller           Thomas Müller   24  13-09-1989        186
# 26            M. Özil              Mesut Özil   25  15-10-1988        183
# 31           M. Götze             Mario Götze   22  03-06-1992        176
# 33           T. Kroos              Toni Kroos   24  04-01-1990        182
# 41         J. Boateng          Jérôme Boateng   25  03-09-1988        192
#
#     weight_kg nationality               club  ...   lwb   ldm   cdm   rdm  \
# 4          92     Germany  FC Bayern München  ...   NaN   NaN   NaN   NaN
# 8          79     Germany  FC Bayern München  ...  81+2  84+2  84+2  84+2
# 13         66     Germany  FC Bayern München  ...  88+2  85+2  85+2  85+2
# 21         90     Germany  Borussia Dortmund  ...  79+2  82+2  82+2  82+2
# 23         73     Germany  Borussia Dortmund  ...  64+1  63+1  63+1  63+1
# 24         75     Germany  FC Bayern München  ...  68+2  69+2  69+2  69+2
# 26         76     Germany            Arsenal  ...  59+1  62+1  62+1  62+1
# 31         72     Germany  FC Bayern München  ...  63+1  65+1  65+1  65+1
# 33         78     Germany        Real Madrid  ...  74+2  76+2  76+2  76+2
# 41         90     Germany  FC Bayern München  ...  78+2  77+2  77+2  77+2
#
#      rwb    lb   lcb    cb   rcb    rb
# 4    NaN   NaN   NaN   NaN   NaN   NaN
# 8   81+2  81+2  79+2  79+2  79+2  81+2
# 13  88+2  85+2  81+2  81+2  81+2  85+2
# 21  79+2  81+2  84+2  84+2  84+2  81+2
# 23  64+1  56+1  48+1  48+1  48+1  56+1
# 24  68+2  65+2  58+2  58+2  58+2  65+2
# 26  59+1  51+1  44+1  44+1  44+1  51+1
# 31  63+1  55+1  48+1  48+1  48+1  55+1
# 33  74+2  68+2  63+2  63+2  63+2  68+2
# 41  78+2  80+2  83+2  83+2  83+2  80+2
#
# [10 rows x 104 columns]

# %%
Germany.sort_values(by=['height_cm'],ascending=False).head()
# Out:
#       sofifa_id                                         player_url  \
# 8814     150389  https://sofifa.com/player/150389/benedikt-pliq...
# 8877     169223  https://sofifa.com/player/169223/thorsten-stuc...
# 7642     200212  https://sofifa.com/player/200212/michael-esser...
# 79        53612  https://sofifa.com/player/53612/per-mertesacke...
# 2029     199833  https://sofifa.com/player/199833/lars-unnersta...
#
#           short_name           long_name  age         dob  height_cm  \
# 8814     B. Pliquett   Benedikt Pliquett   29  20-12-1984        199
# 8877    T. Stuckmann  Thorsten Stuckmann   33  17-03-1981        199
# 7642        M. Esser       Michael Esser   26  22-11-1987        198
# 79    P. Mertesacker     Per Mertesacker   29  29-09-1984        198
# 2029   L. Unnerstall     Lars Unnerstall   23  20-07-1990        198
#
#       weight_kg nationality                club  ...   lwb   ldm   cdm   rdm  \
# 8814         95     Germany       SK Sturm Graz  ...   NaN   NaN   NaN   NaN
# 8877         97     Germany   Preston North End  ...   NaN   NaN   NaN   NaN
# 7642         97     Germany     VfL Bochum 1848  ...   NaN   NaN   NaN   NaN
# 79           90     Germany             Arsenal  ...  69+1  75+1  75+1  75+1
# 2029        100     Germany  Fortuna Düsseldorf  ...   NaN   NaN   NaN   NaN
#
#        rwb    lb   lcb    cb   rcb    rb
# 8814   NaN   NaN   NaN   NaN   NaN   NaN
# 8877   NaN   NaN   NaN   NaN   NaN   NaN
# 7642   NaN   NaN   NaN   NaN   NaN   NaN
# 79    69+1  75+1  82+1  82+1  82+1  75+1
# 2029   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 104 columns]

# %%
Germany.sort_values(by=['weight_kg'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 1745       53012  https://sofifa.com/player/53012/tim-wiese/15/1...
# 2029      199833  https://sofifa.com/player/199833/lars-unnersta...
# 7642      200212  https://sofifa.com/player/200212/michael-esser...
# 8877      169223  https://sofifa.com/player/169223/thorsten-stuc...
# 13726     224251  https://sofifa.com/player/224251/robin-zentner...
#
#           short_name           long_name  age         dob  height_cm  \
# 1745        T. Wiese           Tim Wiese   32  17-12-1981        193
# 2029   L. Unnerstall     Lars Unnerstall   23  20-07-1990        198
# 7642        M. Esser       Michael Esser   26  22-11-1987        198
# 8877    T. Stuckmann  Thorsten Stuckmann   33  17-03-1981        199
# 13726     R. Zentner       Robin Zentner   19  28-10-1994        194
#
#        weight_kg nationality                 club  ...  lwb  ldm  cdm  rdm  \
# 1745         110     Germany  TSG 1899 Hoffenheim  ...  NaN  NaN  NaN  NaN
# 2029         100     Germany   Fortuna Düsseldorf  ...  NaN  NaN  NaN  NaN
# 7642          97     Germany      VfL Bochum 1848  ...  NaN  NaN  NaN  NaN
# 8877          97     Germany    Preston North End  ...  NaN  NaN  NaN  NaN
# 13726         96     Germany      1. FSV Mainz 05  ...  NaN  NaN  NaN  NaN
#
#        rwb   lb  lcb   cb  rcb   rb
# 1745   NaN  NaN  NaN  NaN  NaN  NaN
# 2029   NaN  NaN  NaN  NaN  NaN  NaN
# 7642   NaN  NaN  NaN  NaN  NaN  NaN
# 8877   NaN  NaN  NaN  NaN  NaN  NaN
# 13726  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 104 columns]

# %%
Germany.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 15170     222427  https://sofifa.com/player/222427/tim-grupp/15/...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# 8         121944  https://sofifa.com/player/121944/bastian-schwe...
# 13        121939  https://sofifa.com/player/121939/philipp-lahm/...
# 21        178603  https://sofifa.com/player/178603/mats-hummels/...
#
#               short_name               long_name  age         dob  height_cm  \
# 15170           T. Grupp               Tim Grupp   19  05-01-1995        183
# 4               M. Neuer            Manuel Neuer   28  27-03-1986        193
# 8      B. Schweinsteiger  Bastian Schweinsteiger   29  01-08-1984        183
# 13               P. Lahm            Philipp Lahm   30  11-11-1983        170
# 21            M. Hummels           Mats  Hummels   25  16-12-1988        192
#
#        weight_kg nationality               club  ...   lwb   ldm   cdm   rdm  \
# 15170         70     Germany      Karlsruher SC  ...  49+0  50+0  50+0  50+0
# 4             92     Germany  FC Bayern München  ...   NaN   NaN   NaN   NaN
# 8             79     Germany  FC Bayern München  ...  81+2  84+2  84+2  84+2
# 13            66     Germany  FC Bayern München  ...  88+2  85+2  85+2  85+2
# 21            90     Germany  Borussia Dortmund  ...  79+2  82+2  82+2  82+2
#
#         rwb    lb   lcb    cb   rcb    rb
# 15170  49+0  50+0  51+0  51+0  51+0  50+0
# 4       NaN   NaN   NaN   NaN   NaN   NaN
# 8      81+2  81+2  79+2  79+2  79+2  81+2
# 13     88+2  85+2  81+2  81+2  81+2  85+2
# 21     79+2  81+2  84+2  84+2  84+2  81+2
#
# [5 rows x 104 columns]

# %%
Germany.sort_values(by=['short_name'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 5698      206209  https://sofifa.com/player/206209/zhi-gin-lam/1...
# 7455      208764  https://sofifa.com/player/208764/zlatan-alomer...
# 1654      190748  https://sofifa.com/player/190748/yasin-oztekin...
# 13174     224593  https://sofifa.com/player/224593/yannick-zumma...
# 2994      204153  https://sofifa.com/player/204153/yannick-stark...
#
#           short_name          long_name  age         dob  height_cm  \
# 5698          Z. Lam        Zhi Gin Lam   23  04-06-1991        175
# 7455   Z. Alomerovic  Zlatan Alomerovic   23  15-06-1991        187
# 1654      Y. Öztekin      Yasin Öztekin   27  19-03-1987        179
# 13174     Y. Zummack    Yannick Zummack   18  26-03-1996        186
# 2994        Y. Stark      Yannick Stark   23  28-10-1990        186
#
#        weight_kg nationality                  club  ...   lwb   ldm   cdm  \
# 5698          67     Germany  SpVgg Greuther Fürth  ...  69+0  63+0  63+0
# 7455          88     Germany     Borussia Dortmund  ...   NaN   NaN   NaN
# 1654          65     Germany        Galatasaray SK  ...  64+0  61+0  61+0
# 13174         76     Germany   Eintracht Frankfurt  ...   NaN   NaN   NaN
# 2994          79     Germany      TSV 1860 München  ...  68+0  70+0  70+0
#
#         rdm   rwb    lb   lcb    cb   rcb    rb
# 5698   63+0  69+0  66+0  61+0  61+0  61+0  66+0
# 7455    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1654   61+0  64+0  60+0  56+0  56+0  56+0  60+0
# 13174   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2994   70+0  68+0  70+0  70+0  70+0  70+0  70+0
#
# [5 rows x 104 columns]

# %%
Germany.sort_values(by=['long_name'],ascending=False).head()
# Out:
#       sofifa_id                                         player_url  \
# 65       186942  https://sofifa.com/player/186942/ilkay-gundoga...
# 4676     204436  https://sofifa.com/player/204436/ozkan-yildiri...
# 3584     184518  https://sofifa.com/player/184518/omer-sismanog...
# 7455     208764  https://sofifa.com/player/208764/zlatan-alomer...
# 5698     206209  https://sofifa.com/player/206209/zhi-gin-lam/1...
#
#          short_name              long_name  age         dob  height_cm  \
# 65      I. Gündoğan         İlkay Gündoğan   23  24-10-1990        180
# 4676    O. Yildirim         Özkan Yildirim   21  10-04-1993        173
# 3584  O. Şişmanoğlu  Ömer Hasan Şişmanoğlu   24  01-08-1989        186
# 7455  Z. Alomerovic      Zlatan Alomerovic   23  15-06-1991        187
# 5698         Z. Lam            Zhi Gin Lam   23  04-06-1991        175
#
#       weight_kg nationality                  club  ...   lwb   ldm   cdm  \
# 65           79     Germany     Borussia Dortmund  ...  76+1  78+1  78+1
# 4676         73     Germany      SV Werder Bremen  ...  54+0  53+0  53+0
# 3584         75     Germany         Eskişehirspor  ...  52+0  51+0  51+0
# 7455         88     Germany     Borussia Dortmund  ...   NaN   NaN   NaN
# 5698         67     Germany  SpVgg Greuther Fürth  ...  69+0  63+0  63+0
#
#        rdm   rwb    lb   lcb    cb   rcb    rb
# 65    78+1  76+1  72+1  69+1  69+1  69+1  72+1
# 4676  53+0  54+0  48+0  43+0  43+0  43+0  48+0
# 3584  51+0  52+0  50+0  48+0  48+0  48+0  50+0
# 7455   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5698  63+0  69+0  66+0  61+0  61+0  61+0  66+0
#
# [5 rows x 104 columns]

# %%
Germany[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#               short_name  wage_eur
# 15170           T. Grupp         0
# 4               M. Neuer         0
# 8      B. Schweinsteiger         0
# 13               P. Lahm         0
# 21            M. Hummels         0

# %%
# shooting

# %%
player_shooting=fifa[['short_name','shooting']]

# %%
player_shooting.sort_values(by=['shooting'],ascending=False).head()
# Out:
#            short_name  shooting
# 1   Cristiano Ronaldo      93.0
# 3      Z. Ibrahimović      91.0
# 7       R. van Persie      90.0
# 0            L. Messi      89.0
# 29          W. Rooney      87.0

# %%
# defending

# %%
player_defending = fifa[['short_name','defending','nationality','club']]

# %%
player_defending.sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending nationality                 club
# 15  Thiago Silva       90.0      Brazil  Paris Saint-Germain
# 49    M. Benatia       88.0     Morocco    FC Bayern München
# 21    M. Hummels       88.0     Germany    Borussia Dortmund
# 14  Sergio Ramos       87.0       Spain          Real Madrid
# 13       P. Lahm       87.0     Germany    FC Bayern München

# %%
real_madrid=fifa[fifa['club'] == 'Real Madrid']
real_madrid.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#     sofifa_id                                         player_url  \
# 1       20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 11     173731  https://sofifa.com/player/173731/gareth-bale/1...
# 14     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 17     177003  https://sofifa.com/player/177003/luka-modric/1...
# 18     198710  https://sofifa.com/player/198710/james-rodrigu...
#
#            short_name                            long_name  age         dob  \
# 1   Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  05-02-1985
# 11            G. Bale                    Gareth Frank Bale   24  16-07-1989
# 14       Sergio Ramos                  Sergio Ramos García   28  30-03-1986
# 17          L. Modrić                          Luka Modrić   28  09-09-1985
# 18       J. Rodríguez          James David Rodríguez Rubio   22  12-07-1991
#
#     height_cm  weight_kg nationality         club  ...   lwb   ldm   cdm  \
# 1         185         80    Portugal  Real Madrid  ...  63+3  63+3  63+3
# 11        183         74       Wales  Real Madrid  ...  76+2  75+2  75+2
# 14        183         75       Spain  Real Madrid  ...  81+2  80+2  80+2
# 17        174         65     Croatia  Real Madrid  ...  81+2  80+2  80+2
# 18        180         75    Colombia  Real Madrid  ...  64+2  68+2  68+2
#
#      rdm   rwb    lb   lcb    cb   rcb    rb
# 1   63+3  63+3  57+3  52+3  52+3  52+3  57+3
# 11  75+2  76+2  74+2  70+2  70+2  70+2  74+2
# 14  80+2  81+2  84+2  85+2  85+2  85+2  84+2
# 17  80+2  81+2  76+2  72+2  72+2  72+2  76+2
# 18  68+2  64+2  59+2  53+2  53+2  53+2  59+2
#
# [5 rows x 104 columns]

# %%
real_madrid.sort_values(by=['shooting'],ascending=False).head()
# Out:
#     sofifa_id                                         player_url  \
# 1       20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 34     165153  https://sofifa.com/player/165153/karim-benzema...
# 11     173731  https://sofifa.com/player/173731/gareth-bale/1...
# 33     182521  https://sofifa.com/player/182521/toni-kroos/15...
# 18     198710  https://sofifa.com/player/198710/james-rodrigu...
#
#            short_name                            long_name  age         dob  \
# 1   Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  05-02-1985
# 34         K. Benzema                        Karim Benzema   26  19-12-1987
# 11            G. Bale                    Gareth Frank Bale   24  16-07-1989
# 33           T. Kroos                           Toni Kroos   24  04-01-1990
# 18       J. Rodríguez          James David Rodríguez Rubio   22  12-07-1991
#
#     height_cm  weight_kg nationality         club  ...   lwb   ldm   cdm  \
# 1         185         80    Portugal  Real Madrid  ...  63+3  63+3  63+3
# 34        184         79      France  Real Madrid  ...  58+2  58+2  58+2
# 11        183         74       Wales  Real Madrid  ...  76+2  75+2  75+2
# 33        182         78     Germany  Real Madrid  ...  74+2  76+2  76+2
# 18        180         75    Colombia  Real Madrid  ...  64+2  68+2  68+2
#
#      rdm   rwb    lb   lcb    cb   rcb    rb
# 1   63+3  63+3  57+3  52+3  52+3  52+3  57+3
# 34  58+2  58+2  53+2  49+2  49+2  49+2  53+2
# 11  75+2  76+2  74+2  70+2  70+2  70+2  74+2
# 33  76+2  74+2  68+2  63+2  63+2  63+2  68+2
# 18  68+2  64+2  59+2  53+2  53+2  53+2  59+2
#
# [5 rows x 104 columns]

# %%
real_madrid.sort_values(by=['defending'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 14      155862  https://sofifa.com/player/155862/sergio-ramos-...
# 81      120533  https://sofifa.com/player/120533/kepler-lavera...
# 50      179846  https://sofifa.com/player/179846/sami-khedira/...
# 152     201535  https://sofifa.com/player/201535/raphael-varan...
# 371     146741  https://sofifa.com/player/146741/alvaro-arbelo...
#
#        short_name                     long_name  age         dob  height_cm  \
# 14   Sergio Ramos           Sergio Ramos García   28  30-03-1986        183
# 81           Pepe  Képler Laveran Lima Ferreira   31  26-02-1983        188
# 50     S. Khedira                  Sami Khedira   27  04-04-1987        189
# 152     R. Varane                Raphaël Varane   21  25-04-1993        191
# 371       Arbeloa           Álvaro Arbeloa Coca   31  17-01-1983        184
#
#      weight_kg nationality         club  ...   lwb   ldm   cdm   rdm   rwb  \
# 14          75       Spain  Real Madrid  ...  81+2  80+2  80+2  80+2  81+2
# 81          81    Portugal  Real Madrid  ...  72+1  73+1  73+1  73+1  72+1
# 50          85     Germany  Real Madrid  ...  77+1  83+1  83+1  83+1  77+1
# 152         78      France  Real Madrid  ...  72+1  76+1  76+1  76+1  72+1
# 371         79       Spain  Real Madrid  ...  76+1  75+1  75+1  75+1  76+1
#
#        lb   lcb    cb   rcb    rb
# 14   84+2  85+2  85+2  85+2  84+2
# 81   77+1  82+1  82+1  82+1  77+1
# 50   79+1  81+1  81+1  81+1  79+1
# 152  76+1  80+1  80+1  80+1  76+1
# 371  78+1  77+1  77+1  77+1  78+1
#
# [5 rows x 104 columns]

# %%
real_madrid['nationality'].value_counts()
# Out:
# nationality
# Spain         17
# Portugal       3
# France         2
# Germany        2
# Brazil         2
# Wales          1
# Croatia        1
# Colombia       1
# Mexico         1
# Costa Rica     1
# Finland        1
# Uruguay        1
# Name: count, dtype: int64
